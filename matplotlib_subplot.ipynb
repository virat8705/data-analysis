# %%
import matplotlib.pyplot as plt

# %%
x=[1,3,5,7,9]
y=[3,5,7,8,9]

plt.subplot(2,2,1)
plt.plot(x,y,color='r')

plt.subplot(2,2,2)
plt.pie([1],colors='y')


x1=[10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x)


x2=['a','s','d','f']
y2=[10,20,30,40]
plt.subplot(2,2,4)
plt.bar(x2,y2)

plt.savefig('line',dpi=2000,facecolor='c')
plt.show()
