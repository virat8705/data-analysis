# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x= np.random.randint(10,60,(50))
print(x)
# Out:
# [30 18 58 43 43 23 19 46 53 27 51 30 44 27 49 42 21 46 42 29 10 45 16 17
#  45 40 20 35 59 12 43 18 32 46 52 46 33 56 42 14 59 20 38 18 16 17 31 20
#  16 43]

# %%
no = [30, 18, 58, 43, 43, 23, 19, 46, 53, 27, 51, 30, 44, 27, 49, 42, 21, 46, 42, 29, 10, 45, 16, 17, 45, 40, 20, 35, 59, 12, 43, 18, 32, 46, 52, 46, 33, 56, 42, 14, 59, 20, 38, 18, 16, 17, 31, 20, 16, 43]

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins=l,edgecolor='r')
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),color = 'c',edgecolor='r')
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',edgecolor='r',cumulative = 1)
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',edgecolor='r',bottom = 10)
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',align ='left' )
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',histtype = 'step' )
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',histtype = 'stepfilled' )
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',histtype = 'barstacked' )
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',orientation = 'horizontal')
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',rwidth = 0.8)
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',log = True)
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',label = 'Python')
plt.legend()
plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',label = 'Python')


plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.axvline(45,color='k',label='line')
plt.legend()
plt.show()

# %%
l = [10,20,30,40,50,60]
plt.hist(no,color = 'c',bins= l,edgecolor='r',label = 'Python')


plt.title('random histogram',color = 'g')
plt.xlabel("python")
plt.ylabel("No.")
plt.axvline(45,color='k',label='line')
plt.legend()
plt.grid()
plt.show()
